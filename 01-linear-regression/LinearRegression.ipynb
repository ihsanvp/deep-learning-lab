# %% [markdown]
# # LinearRegression

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

x = np.random.rand(100, 1)
y = 2 + 3 * x + np.random.rand(100, 1)

plt.scatter(x, y, s=10)
plt.xlabel("X")
plt.ylabel("Y")
plt.ylim(ymin=0)
plt.show()

# %% [markdown]
# ## Calculate Slope & Intercept of Regression line

# %%
mean_x = np.mean(x)
mean_y = np.mean(y)

num = np.sum((x - mean_x) * (y - mean_y))
den = np.sum((x - mean_x) **2)

slope = num / den
intercept = np.mean(y) - slope * mean_x

print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# Slope: 2.936551060203768
# Intercept: 2.5580800241570216

# %% [markdown]
# ## Plotting Regression line

# %%
y_pred = intercept + (slope * x)

plt.scatter(x, y, s=20)
plt.plot(x, y_pred, c="red")
plt.xlabel("X")
plt.ylabel("Y")
plt.ylim(ymin=0)
plt.show()
